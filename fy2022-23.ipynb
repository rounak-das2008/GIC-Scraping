# %%
import numpy as np
import pandas as pd
import requests 
from bs4 import BeautifulSoup
from time import sleep
import os

# %%
dfs = pd.read_html("https://www.gicouncil.in/yearbook/2018-19/annexures/table-15-net-underwriting-experiencee-2008-09-to-2017-18-overall-figures/")
for df in dfs:
    print(df)
# Out:
#                                             0           1           2   \
# 0                                         Year     2008-09     2009-10
# 1                          Net Written Premium    26162.69    30697.15
# 2                           Net Earned Premium    24438.66    28286.56
# 3                          Net Incurred Claims    20892.28    24685.56
# 4              Net Incurred Claims as % to NEP      85.49%      87.27%
# 5                               Net Commission     1046.73     1198.76
# 6                   Net Commission as % to NWP       4.00%       3.91%
# 7                       Expenses of Management     7611.94     8749.25
# 8                              EOM as % to NEP      31.15%      30.93%
# 9               Underwriting Surplus/(Deficit)  (5,112.29)  (6,347.01)
# 10  Underwriting Surplus/(Deficit) as % to NEP     -20.92%     -22.44%
#
#              3           4           5           6            7            8   \
# 0       2010-11     2011-12     2012-13     2013-14      2014-15      2015-16
# 1      38150.49    47852.19    55890.16    64863.56     71300.23     81450.16
# 2      34585.43    42641.17    51226.17    60009.74     67428.11     75877.60
# 3      32100.28    37738.90    42549.95    49163.80     55231.87     64495.03
# 4        92.81%      88.50%      83.06%      81.93%       81.91%       85.00%
# 5       1332.02     1772.19     1708.13     2578.11      2663.81      2973.01
# 6         3.49%       3.70%       3.06%       3.97%        3.74%        3.65%
# 7      11163.25    12119.25    14602.72    15920.90     20195.94     23231.73
# 8        32.28%      28.42%      28.51%      26.53%       29.95%       30.62%
# 9   (10,010.12)  (8,989.17)  (7,634.62)  (7,653.07)  (10,663.51)  (14,822.17)
# 10      -28.94%     -21.08%     -14.90%     -12.75%      -15.81%      -19.53%
#
#              9            10           11
# 0       2016-17      2017-18      2018-19
# 1      94177.57    107410.75    120386.40
# 2      88724.95    100452.71    113333.77
# 3      80662.18     85650.15    101051.02
# 4        90.91%       85.26%       89.16%
# 5       1380.24      3966.62      5694.77
# 6         1.47%        3.69%        4.73%
# 7      25079.43     25719.18     28624.09
# 8        28.27%       25.60%       25.26%
# 9   (18,396.91)  (14,883.25)  (22,036.11)
# 10      -20.73%      -14.82%      -19.44%

# %%
df
# Out:
#                                             0           1           2   \
# 0                                         Year     2008-09     2009-10
# 1                          Net Written Premium    26162.69    30697.15
# 2                           Net Earned Premium    24438.66    28286.56
# 3                          Net Incurred Claims    20892.28    24685.56
# 4              Net Incurred Claims as % to NEP      85.49%      87.27%
# 5                               Net Commission     1046.73     1198.76
# 6                   Net Commission as % to NWP       4.00%       3.91%
# 7                       Expenses of Management     7611.94     8749.25
# 8                              EOM as % to NEP      31.15%      30.93%
# 9               Underwriting Surplus/(Deficit)  (5,112.29)  (6,347.01)
# 10  Underwriting Surplus/(Deficit) as % to NEP     -20.92%     -22.44%
#
#              3           4           5           6            7            8   \
# 0       2010-11     2011-12     2012-13     2013-14      2014-15      2015-16
# 1      38150.49    47852.19    55890.16    64863.56     71300.23     81450.16
# 2      34585.43    42641.17    51226.17    60009.74     67428.11     75877.60
# 3      32100.28    37738.90    42549.95    49163.80     55231.87     64495.03
# 4        92.81%      88.50%      83.06%      81.93%       81.91%       85.00%
# 5       1332.02     1772.19     1708.13     2578.11      2663.81      2973.01
# 6         3.49%       3.70%       3.06%       3.97%        3.74%        3.65%
# 7      11163.25    12119.25    14602.72    15920.90     20195.94     23231.73
# 8        32.28%      28.42%      28.51%      26.53%       29.95%       30.62%
# 9   (10,010.12)  (8,989.17)  (7,634.62)  (7,653.07)  (10,663.51)  (14,822.17)
# 10      -28.94%     -21.08%     -14.90%     -12.75%      -15.81%      -19.53%
#
#              9            10           11
# 0       2016-17      2017-18      2018-19
# 1      94177.57    107410.75    120386.40
# 2      88724.95    100452.71    113333.77
# 3      80662.18     85650.15    101051.02
# 4        90.91%       85.26%       89.16%
# 5       1380.24      3966.62      5694.77
# 6         1.47%        3.69%        4.73%
# 7      25079.43     25719.18     28624.09
# 8        28.27%       25.60%       25.26%
# 9   (18,396.91)  (14,883.25)  (22,036.11)
# 10      -20.73%      -14.82%      -19.44%

# %%
df.to_csv('table-15-net-underwriting-experiencee-18-19.csv', index = False, header=None)

# %%
yearbook_url = "https://www.gicouncil.in/yearbook/2019-20/index"

# %%
import re
def collect_annexure_link(index_url):
    r = requests.get(index_url, verify=False)
    soup = BeautifulSoup(r.content, "html.parser")
    sleep(3)
    annex_link = re.sub(r'index$', '', index_url) + "annexures"
    def get_annexure_links(tag):
        return(tag.name == 'a' and 
               'href' in tag.attrs and
               annex_link in tag['href'].lower())
    results = soup.find_all(get_annexure_links)

    results.pop(0)
    for result in results:
        print(result['href'])
    return results

# %%
def collect_dataframes(df_url, folder_name):
    file_name = df_url.split("/")[-2]
    dfs = pd.read_html(df_url)
    for df in dfs:
        df.to_csv(f"{folder_name}/{file_name}.csv", index=False, header=None, mode='a')
        with open(f"{folder_name}/{file_name}.csv", 'a') as f:
            f.write('\n')
    sleep(3)
    return file_name

# %%
annexure_links = collect_annexure_link(yearbook_url)
folder_name = yearbook_url.split("/")[-2]
os.mkdir(folder_name)
print("In Main --------")
for annexure_link_a in annexure_links:
    print(annexure_link_a)
    table_link = annexure_link_a['href']
    file_name = collect_dataframes(table_link, folder_name)
    print(" ====== ", file_name, ": Done =========\n")
print(" ====== ", folder_name, ": Done =========\n")
# Out:
# C:\Users\roundas\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webproxy.tataaig.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\roundas\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webproxy.tataaig.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# https://www.gicouncil.in/yearbook/2019-20/annexures/table-1-investment-portfolio-of-non-life-insurance-industry/
# https://www.gicouncil.in/yearbook/2019-20/annexures/table-2-capital-employed-by-type-of-company/
# https://www.gicouncil.in/yearbook/2019-20/annexures/table-3-channelwise-gdpi/
# https://www.gicouncil.in/yearbook/2019-20/annexures/table-4-statewise-classwise-gdpi/
# https://www.gicouncil.in/yearbook/2019-20/annexures/table-5-statewise-number-of-offices-gdpi-population-literacy-and-state-domestic-product/
# https://www.gicouncil.in/yearbook/2019-20/annexures/table-6-non-life-insurance-industry-data/
# https://www.gicouncil.in/yearbook/2019-20/annexures/table-7-gross-written-premium/
# https://www.gicouncil.in/yearbook/2019-20/annexures/table-8-gross-incurred-claim-ratios-within-india-and-abroad/
# https://www.gicouncil.in/yearbook/2019-20/annexures/table-gross-commission-ratios-within-india-and-abroad/
# https://www.gicouncil.in/yearbook/2019-20/annexures/table-10-net-retention-ratios-defined-as-net-written-premium-divided-by-gross-written-premium/
# https://www.gicouncil.in/yearbook/2019-20/annexures/table-11-net-earned-premium-income/
# https://www.gicouncil.in/yearbook/2019-20/annexures/table-12-net-incurred-claim-ratios-defined-as-net-incurred-claims-divided-by-net-earned-premium/
# https://www.gicouncil.in/yearbook/2019-20/annexures/table-13-net-commission-ratios-defined-as-net-commission-to-net-earned-premium/
# https://www.gicouncil.in/yearbook/2019-20/annexures/table-14-gross-underwriting-experience-2008-09-to-2017-18-overall-figures/
# https://www.gicouncil.in/yearbook/2019-20/annexures/table-15-net-underwriting-experiencee-2008-09-to-2017-18-overall-figures/
# In Main --------
# <a class="responsive-menu-item-link" href="https://www.gicouncil.in/yearbook/2019-20/annexures/table-1-investment-portfolio-of-non-life-insurance-industry/">Table 1: Investment Portfolio of Non-Life Insurance Industry</a>
#  ======  table-1-investment-portfolio-of-non-life-insurance-industry : Done =========
#
# <a class="responsive-menu-item-link" href="https://www.gicouncil.in/yearbook/2019-20/annexures/table-2-capital-employed-by-type-of-company/">Table 2: Capital Employed by Type of Company</a>
#  ======  table-2-capital-employed-by-type-of-company : Done =========
#
# <a class="responsive-menu-item-link" href="https://www.gicouncil.in/yearbook/2019-20/annexures/table-3-channelwise-gdpi/">Table 3: Channelwise GDPI</a>
#  ======  table-3-channelwise-gdpi : Done =========
#
# <a class="responsive-menu-item-link" href="https://www.gicouncil.in/yearbook/2019-20/annexures/table-4-statewise-classwise-gdpi/">Table 4: Statewise Classwise GDPI</a>
#  ======  table-4-statewise-classwise-gdpi : Done =========
#
# <a class="responsive-menu-item-link" href="https://www.gicouncil.in/yearbook/2019-20/annexures/table-5-statewise-number-of-offices-gdpi-population-literacy-and-state-domestic-product/">Table 5: Statewise Number of offices, GDPI, Population, Literacy and State Domestic Product</a>
#  ======  table-5-statewise-number-of-offices-gdpi-population-literacy-and-state-domestic-product : Done =========
#
# <a class="responsive-menu-item-link" href="https://www.gicouncil.in/yearbook/2019-20/annexures/table-6-non-life-insurance-industry-data/">Table 6: Non-Life Insurance Industry Data</a>
#  ======  table-6-non-life-insurance-industry-data : Done =========
#
# <a class="responsive-menu-item-link" href="https://www.gicouncil.in/yearbook/2019-20/annexures/table-7-gross-written-premium/">Table 7: Gross Written Premium</a>
#  ======  table-7-gross-written-premium : Done =========
#
# <a class="responsive-menu-item-link" href="https://www.gicouncil.in/yearbook/2019-20/annexures/table-8-gross-incurred-claim-ratios-within-india-and-abroad/">Table 8: Gross incurred Claim Ratios (within India and abroad)</a>
#  ======  table-8-gross-incurred-claim-ratios-within-india-and-abroad : Done =========
#
# <a class="responsive-menu-item-link" href="https://www.gicouncil.in/yearbook/2019-20/annexures/table-gross-commission-ratios-within-india-and-abroad/">Table  9: Gross Commission Ratios (within India and Abroad)</a>
#  ======  table-gross-commission-ratios-within-india-and-abroad : Done =========
#
# <a class="responsive-menu-item-link" href="https://www.gicouncil.in/yearbook/2019-20/annexures/table-10-net-retention-ratios-defined-as-net-written-premium-divided-by-gross-written-premium/">Table 10: Net Retention Ratios (defined as Net Written premium divided by Gross Written Premium)</a>
#  ======  table-10-net-retention-ratios-defined-as-net-written-premium-divided-by-gross-written-premium : Done =========
#
# <a class="responsive-menu-item-link" href="https://www.gicouncil.in/yearbook/2019-20/annexures/table-11-net-earned-premium-income/">Table 11: Net Earned Premium Income</a>
#  ======  table-11-net-earned-premium-income : Done =========
#
# <a class="responsive-menu-item-link" href="https://www.gicouncil.in/yearbook/2019-20/annexures/table-12-net-incurred-claim-ratios-defined-as-net-incurred-claims-divided-by-net-earned-premium/">Table 12: Net Incurred Claim Ratios (defined as Net Incurred Claims divided by Net Earned Premium)</a>
#  ======  table-12-net-incurred-claim-ratios-defined-as-net-incurred-claims-divided-by-net-earned-premium : Done =========
#
# <a class="responsive-menu-item-link" href="https://www.gicouncil.in/yearbook/2019-20/annexures/table-13-net-commission-ratios-defined-as-net-commission-to-net-earned-premium/">Table 13: Net Commission Ratios (defined as Net Commission to Net Earned Premium)</a>
#  ======  table-13-net-commission-ratios-defined-as-net-commission-to-net-earned-premium : Done =========
#
# <a class="responsive-menu-item-link" href="https://www.gicouncil.in/yearbook/2019-20/annexures/table-14-gross-underwriting-experience-2008-09-to-2017-18-overall-figures/">Table 14: Gross Underwriting Experience – 2009-10 to 2019-20  (Overall Figures)</a>
#  ======  table-14-gross-underwriting-experience-2008-09-to-2017-18-overall-figures : Done =========
#
# <a class="responsive-menu-item-link" href="https://www.gicouncil.in/yearbook/2019-20/annexures/table-15-net-underwriting-experiencee-2008-09-to-2017-18-overall-figures/">Table 15: Net Underwriting Experience – 2009-10 to 2019-20 (Overall Figures)</a>
#  ======  table-15-net-underwriting-experiencee-2008-09-to-2017-18-overall-figures : Done =========
#
#  ======  2019-20 : Done =========

# %%
annexure_links
# Out:
# <a class="responsive-menu-item-link" href="https://www.gicouncil.in/yearbook/2022-23/annexures/table16reinsurers-in-india/" role="menuitem" tabindex="1">Table 16: Reinsurers Premium Statement as of 31st March 2023</a>

# %%
import re
url = "https://www.gicouncil.in/yearbook/2019-20/index"
new_url = re.sub(r'index$', '', url) + "annexures"
print(new_url)
# Out:
# https://www.gicouncil.in/yearbook/2019-20/annexures

# %%
import re
def collect_annexure_link(index_url):
    r = requests.get(index_url, verify=False)
    soup = BeautifulSoup(r.content, "html.parser")
    sleep(3)
    annex_link1 = re.sub(r'index$', '', index_url) + "annexures"
    annex_link2 = annex_link1 + "index.php/annexures/"
    try:
        def get_annexure_links(tag):
            return(tag.name == 'a' and 
                   'href' in tag.attrs and
                   annex_link1 in tag['href'].lower())
        results = soup.find_all(get_annexure_links)
    
        results.pop(0)
        for result in results:
            print(result['href'])
        return results
    except:
        def get_annexure_links(tag):
            return(tag.name == 'a' and 
                   'href' in tag.attrs and
                   annex_link2 in tag['href'].lower())
        results = soup.find_all(get_annexure_links)
    
        results.pop(0)
        for result in results:
            print(result['href'])
        return results

# %%
def collect_dataframes(df_url, folder_name):
    file_name = df_url.split("/")[-2]
    dfs = pd.read_html(df_url)
    for df in dfs:
        df.to_csv(f"{folder_name}/{file_name}.csv", index=False, header=None, mode='a')
        with open(f"{folder_name}/{file_name}.csv", 'a') as f:
            f.write('\n')
    sleep(3)
    return file_name

# %%
yearbook_url = "https://www.gicouncil.in/yearbook/2020-21/index/"
annexure_links = collect_annexure_link(yearbook_url)
folder_name = yearbook_url.split("/")[-2]
os.mkdir(folder_name)
print("In Main --------")
for annexure_link_a in annexure_links:
    print(annexure_link_a)
    table_link = annexure_link_a['href']
    file_name = collect_dataframes(table_link, folder_name)
    print(" ====== ", file_name, ": Done =========\n")
print(" ====== ", folder_name, ": Done =========\n")
# Out:
# C:\Users\roundas\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webproxy.tataaig.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 15, in collect_annexure_link(index_url)
#      13 results = soup.find_all(get_annexure_links)
# ---> 15 results.pop(0)
#      16 for result in results:
#
# IndexError: pop from empty list
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 yearbook_url = "https://www.gicouncil.in/yearbook/2020-21/index/"
# ----> 2 annexure_links = collect_annexure_link(yearbook_url)
#       3 folder_name = yearbook_url.split("/")[-2]
#       4 os.mkdir(folder_name)
#
# Cell In[2], line 26, in collect_annexure_link(index_url)
#      21     return(tag.name == 'a' and
#      22            'href' in tag.attrs and
#      23            annex_link2 in tag['href'].lower())
#      24 results = soup.find_all(get_annexure_links)
# ---> 26 results.pop(0)
#      27 for result in results:
#      28     print(result['href'])
#
# IndexError: pop from empty list

# %%
import re
def collect_annexure_link(index_url):
    r = requests.get(index_url, verify=False)
    soup = BeautifulSoup(r.content, "html.parser")
    sleep(3)
    annex_link = re.sub(r'index$', '', index_url) + "annexures"
    def get_annexure_links(tag):
        return(tag.name == 'a' and 
               'href' in tag.attrs and
               annex_link in tag['href'].lower())
    results = soup.find_all(get_annexure_links)

    results.pop(0)
    for result in results:
        print(result['href'])
    return results

# %%
def collect_dataframes(df_url, folder_name):
    file_name = df_url.split("/")[-2]
    dfs = pd.read_html(df_url)
    for df in dfs:
        df.to_csv(f"{folder_name}/{file_name}.csv", index=False, header=None, mode='a')
        with open(f"{folder_name}/{file_name}.csv", 'a') as f:
            f.write('\n')
    sleep(3)
    return file_name

# %%
yearbook_url = "https://www.gicouncil.in/yearbook/2019-20/index/"
annexure_links = collect_annexure_link(yearbook_url)
folder_name = yearbook_url.split("/")[-2]
os.mkdir(folder_name)
print("In Main --------")
for annexure_link_a in annexure_links:
    print(annexure_link_a)
    table_link = annexure_link_a['href']
    file_name = collect_dataframes(table_link, folder_name)
    print(" ====== ", file_name, ": Done =========\n")
print(" ====== ", folder_name, ": Done =========\n")
# Out:
# C:\Users\roundas\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webproxy.tataaig.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 yearbook_url = "https://www.gicouncil.in/yearbook/2019-20/index/"
# ----> 2 annexure_links = collect_annexure_link(yearbook_url)
#       3 folder_name = yearbook_url.split("/")[-2]
#       4 os.mkdir(folder_name)
#
# Cell In[2], line 13, in collect_annexure_link(index_url)
#       8     return(tag.name == 'a' and
#       9            'href' in tag.attrs and
#      10            annex_link in tag['href'].lower())
#      11 results = soup.find_all(get_annexure_links)
# ---> 13 results.pop(0)
#      14 for result in results:
#      15     print(result['href'])
#
# IndexError: pop from empty list

# %%
url = "https://www.gicouncil.in/yearbook/2021-22/index/"
response = requests.get(url, verify=False)

# Check if the request was successful
if response.status_code == 200:
    page_content = response.content
    soup = BeautifulSoup(page_content, 'html.parser')

    # Find all links (a tags) in the page
    links = soup.find_all('a', href=True)

    # Filter links containing 'annexure'
    annexure_links = [link['href'] for link in links if 'https://www.gicouncil.in/yearbook/2021-22/annexures/' in link['href'].lower()]

    # Print the annexure links
    for link in annexure_links:
        print(link)
else:
    print("Failed to retrieve the webpage.")
# Out:
# C:\Users\roundas\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webproxy.tataaig.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\roundas\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webproxy.tataaig.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# https://www.gicouncil.in/yearbook/2021-22/annexures/table16reinsurers-in-india/
# https://www.gicouncil.in/yearbook/2021-22/annexures/
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-1-investment-portfolio-of-non-life-insurance-industry/
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-2-capital-employed-by-type-of-company/
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-3-channelwise-gdpi/
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-4-statewise-classwise-gdpi/
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-5-statewise-number-of-offices-gdpi-population-literacy-and-state-domestic-product/
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-6-non-life-insurance-industry-data/
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-7-gross-written-premium/
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-8-gross-incurred-claim-ratios-within-india-and-abroad/
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-gross-commission-ratios-within-india-and-abroad/
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-10-net-retention-ratios-defined-as-net-written-premium-divided-by-gross-written-premium/
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-11-net-earned-premium-income/
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-12-net-incurred-claim-ratios-defined-as-net-incurred-claims-divided-by-net-earned-premium/
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-13-net-commission-ratios-defined-as-net-commission-to-net-earned-premium/
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-14-gross-underwriting-experience-2008-09-to-2017-18-overall-figures/
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-15-net-underwriting-experiencee-2008-09-to-2017-18-overall-figures/
# https://www.gicouncil.in/yearbook/2021-22/annexures/table16reinsurers-in-india/

# %%
# # annexure_links
# for links in annexure_links:
#     final_annexure_links =

# %%
def collect_dataframes(df_url, folder_name):
    file_name = df_url.split("/")[-2]
    try:
        dfs = pd.read_html(df_url)
        for df in dfs:
            df.to_csv(f"{folder_name}/{file_name}.csv", index=False, header=None, mode='a')
            with open(f"{folder_name}/{file_name}.csv", 'a') as f:
                f.write('\n')
        sleep(3)
        return file_name
    except:
        pass

# %%
yearbook_url = "https://www.gicouncil.in/yearbook/2021-22/index/"
# annexure_links = collect_annexure_link(yearbook_url)
folder_name = yearbook_url.split("/")[-3]
os.mkdir(folder_name)
print("In Main --------")
for annexure_link_a in annexure_links:
    print(annexure_link_a)
    # table_link = annexure_link_a['href']
    file_name = collect_dataframes(annexure_link_a, folder_name)
    print(" ====== ", file_name, ": Done =========\n")
print(" ====== ", folder_name, ": Done =========\n")
# Out:
# In Main --------
# https://www.gicouncil.in/yearbook/2021-22/annexures/table16reinsurers-in-india/
#  ======  table16reinsurers-in-india : Done =========
#
# https://www.gicouncil.in/yearbook/2021-22/annexures/
#  ======  None : Done =========
#
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-1-investment-portfolio-of-non-life-insurance-industry/
#  ======  table-1-investment-portfolio-of-non-life-insurance-industry : Done =========
#
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-2-capital-employed-by-type-of-company/
#  ======  table-2-capital-employed-by-type-of-company : Done =========
#
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-3-channelwise-gdpi/
#  ======  table-3-channelwise-gdpi : Done =========
#
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-4-statewise-classwise-gdpi/
#  ======  table-4-statewise-classwise-gdpi : Done =========
#
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-5-statewise-number-of-offices-gdpi-population-literacy-and-state-domestic-product/
#  ======  table-5-statewise-number-of-offices-gdpi-population-literacy-and-state-domestic-product : Done =========
#
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-6-non-life-insurance-industry-data/
#  ======  table-6-non-life-insurance-industry-data : Done =========
#
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-7-gross-written-premium/
#  ======  table-7-gross-written-premium : Done =========
#
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-8-gross-incurred-claim-ratios-within-india-and-abroad/
#  ======  table-8-gross-incurred-claim-ratios-within-india-and-abroad : Done =========
#
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-gross-commission-ratios-within-india-and-abroad/
#  ======  None : Done =========
#
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-10-net-retention-ratios-defined-as-net-written-premium-divided-by-gross-written-premium/
#  ======  table-10-net-retention-ratios-defined-as-net-written-premium-divided-by-gross-written-premium : Done =========
#
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-11-net-earned-premium-income/
#  ======  table-11-net-earned-premium-income : Done =========
#
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-12-net-incurred-claim-ratios-defined-as-net-incurred-claims-divided-by-net-earned-premium/
#  ======  table-12-net-incurred-claim-ratios-defined-as-net-incurred-claims-divided-by-net-earned-premium : Done =========
#
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-13-net-commission-ratios-defined-as-net-commission-to-net-earned-premium/
#  ======  table-13-net-commission-ratios-defined-as-net-commission-to-net-earned-premium : Done =========
#
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-14-gross-underwriting-experience-2008-09-to-2017-18-overall-figures/
#  ======  table-14-gross-underwriting-experience-2008-09-to-2017-18-overall-figures : Done =========
#
# https://www.gicouncil.in/yearbook/2021-22/annexures/table-15-net-underwriting-experiencee-2008-09-to-2017-18-overall-figures/
#  ======  table-15-net-underwriting-experiencee-2008-09-to-2017-18-overall-figures : Done =========
#
# https://www.gicouncil.in/yearbook/2021-22/annexures/table16reinsurers-in-india/
#  ======  table16reinsurers-in-india : Done =========
#
#  ======  2021-22 : Done =========

# %%
url = "https://www.gicouncil.in/yearbook/2022-23/index/"
response = requests.get(url, verify=False)

# Check if the request was successful
if response.status_code == 200:
    page_content = response.content
    soup = BeautifulSoup(page_content, 'html.parser')

    # Find all links (a tags) in the page
    links = soup.find_all('a', href=True)

    # Filter links containing 'annexure'
    annexure_links = [link['href'] for link in links if 'https://www.gicouncil.in/yearbook/2022-23/annexures/' in link['href'].lower()]

    # Print the annexure links
    for link in annexure_links:
        print(link)
else:
    print("Failed to retrieve the webpage.")
# Out:
# C:\Users\roundas\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webproxy.tataaig.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\roundas\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webproxy.tataaig.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# https://www.gicouncil.in/yearbook/2022-23/annexures/table16reinsurers-in-india/
# https://www.gicouncil.in/yearbook/2022-23/annexures/
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-1-investment-portfolio-of-non-life-insurance-industry/
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-2-capital-employed-by-type-of-company/
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-3-channelwise-gdpi/
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-4-statewise-classwise-gdpi/
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-5-statewise-number-of-offices-gdpi-population-literacy-and-state-domestic-product/
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-6-non-life-insurance-industry-data/
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-7-gross-written-premium/
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-8-gross-incurred-claim-ratios-within-india-and-abroad/
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-gross-commission-ratios-within-india-and-abroad/
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-10-net-retention-ratios-defined-as-net-written-premium-divided-by-gross-written-premium/
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-11-net-earned-premium-income/
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-12-net-incurred-claim-ratios-defined-as-net-incurred-claims-divided-by-net-earned-premium/
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-13-net-commission-ratios-defined-as-net-commission-to-net-earned-premium/
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-14-gross-underwriting-experience-2008-09-to-2017-18-overall-figures/
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-15-net-underwriting-experiencee-2008-09-to-2017-18-overall-figures/
# https://www.gicouncil.in/yearbook/2022-23/annexures/table16reinsurers-in-india/

# %%
def collect_dataframes(df_url, folder_name):
    file_name = df_url.split("/")[-2]
    try:
        dfs = pd.read_html(df_url)
        for df in dfs:
            df.to_csv(f"{folder_name}/{file_name}.csv", index=False, header=None, mode='a')
            with open(f"{folder_name}/{file_name}.csv", 'a') as f:
                f.write('\n')
        sleep(3)
        return file_name
    except:
        pass

# %%
yearbook_url = "https://www.gicouncil.in/yearbook/2022-23/index/"
# annexure_links = collect_annexure_link(yearbook_url)
folder_name = yearbook_url.split("/")[-3]
os.mkdir(folder_name)
print("In Main --------")
for annexure_link_a in annexure_links:
    print(annexure_link_a)
    # table_link = annexure_link_a['href']
    file_name = collect_dataframes(annexure_link_a, folder_name)
    print(" ====== ", file_name, ": Done =========\n")
print(" ====== ", folder_name, ": Done =========\n")
# Out:
# In Main --------
# https://www.gicouncil.in/yearbook/2022-23/annexures/table16reinsurers-in-india/
#  ======  table16reinsurers-in-india : Done =========
#
# https://www.gicouncil.in/yearbook/2022-23/annexures/
#  ======  None : Done =========
#
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-1-investment-portfolio-of-non-life-insurance-industry/
#  ======  table-1-investment-portfolio-of-non-life-insurance-industry : Done =========
#
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-2-capital-employed-by-type-of-company/
#  ======  table-2-capital-employed-by-type-of-company : Done =========
#
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-3-channelwise-gdpi/
#  ======  table-3-channelwise-gdpi : Done =========
#
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-4-statewise-classwise-gdpi/
#  ======  table-4-statewise-classwise-gdpi : Done =========
#
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-5-statewise-number-of-offices-gdpi-population-literacy-and-state-domestic-product/
#  ======  table-5-statewise-number-of-offices-gdpi-population-literacy-and-state-domestic-product : Done =========
#
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-6-non-life-insurance-industry-data/
#  ======  table-6-non-life-insurance-industry-data : Done =========
#
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-7-gross-written-premium/
#  ======  table-7-gross-written-premium : Done =========
#
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-8-gross-incurred-claim-ratios-within-india-and-abroad/
#  ======  table-8-gross-incurred-claim-ratios-within-india-and-abroad : Done =========
#
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-gross-commission-ratios-within-india-and-abroad/
#  ======  table-gross-commission-ratios-within-india-and-abroad : Done =========
#
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-10-net-retention-ratios-defined-as-net-written-premium-divided-by-gross-written-premium/
#  ======  table-10-net-retention-ratios-defined-as-net-written-premium-divided-by-gross-written-premium : Done =========
#
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-11-net-earned-premium-income/
#  ======  table-11-net-earned-premium-income : Done =========
#
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-12-net-incurred-claim-ratios-defined-as-net-incurred-claims-divided-by-net-earned-premium/
#  ======  table-12-net-incurred-claim-ratios-defined-as-net-incurred-claims-divided-by-net-earned-premium : Done =========
#
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-13-net-commission-ratios-defined-as-net-commission-to-net-earned-premium/
#  ======  table-13-net-commission-ratios-defined-as-net-commission-to-net-earned-premium : Done =========
#
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-14-gross-underwriting-experience-2008-09-to-2017-18-overall-figures/
#  ======  table-14-gross-underwriting-experience-2008-09-to-2017-18-overall-figures : Done =========
#
# https://www.gicouncil.in/yearbook/2022-23/annexures/table-15-net-underwriting-experiencee-2008-09-to-2017-18-overall-figures/
#  ======  None : Done =========
#
# https://www.gicouncil.in/yearbook/2022-23/annexures/table16reinsurers-in-india/
#  ======  None : Done =========
#
#  ======  2022-23 : Done =========

# %%
url = "https://www.gicouncil.in/yearbook/2021-22/annexures/table-1-investment-portfolio-of-non-life-insurance-industry/"
url.split("/")[-2]
# Out:
# 'table-1-investment-portfolio-of-non-life-insurance-industry'

# %%
url = "https://www.gicouncil.in/yearbook/2021-22/index/"
folder_name = yearbook_url.split("/")[-3]
print(folder_name)
# Out:
# 2021-22
